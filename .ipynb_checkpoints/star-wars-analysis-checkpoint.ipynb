# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from math import pi
import matplotlib.colors as mcolors
from scipy import stats

from csv import reader
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
from pathlib import Path
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from pysankey import sankey

from scipy.stats import shapiro
from scipy.stats import ttest_ind
from scipy.stats import f

# Get the data
characters = open('star-wars-dataset/characters.csv')
df_characters = pd.read_csv('star-wars-dataset/characters.csv')
planets = open('star-wars-dataset/planets.csv')
df_planets = pd.read_csv('star-wars-dataset/planets.csv')
species = open('star-wars-dataset/species.csv')
df_species = pd.read_csv('star-wars-dataset/species.csv')
starships = open('star-wars-dataset/starships.csv')
df_starships = pd.read_csv('star-wars-dataset/starships.csv')
vehicles = open('star-wars-dataset/vehicles.csv')
df_vehicles = pd.read_csv('star-wars-dataset/vehicles.csv')


sns.set()

# %%
df_characters.head(10)
# Out:
#                  name  height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker   172.0   77          blond         fair       blue
# 1               C-3PO   167.0   75            NaN         gold     yellow
# 2               R2-D2    96.0   32            NaN  white, blue        red
# 3         Darth Vader   202.0  136           none        white     yellow
# 4         Leia Organa   150.0   49          brown        light      brown
# 5           Owen Lars   178.0  120    brown, grey        light       blue
# 6  Beru Whitesun lars   165.0   75          brown        light       blue
# 7               R5-D4    97.0   32            NaN   white, red        red
# 8   Biggs Darklighter   183.0   84          black        light      brown
# 9      Obi-Wan Kenobi   182.0   77  auburn, white         fair  blue-gray
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY     NaN  Tatooine   Droid
# 2      33BBY     NaN     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human
# 5      52BBY    male  Tatooine   Human
# 6      47BBY  female  Tatooine   Human
# 7        NaN     NaN  Tatooine   Droid
# 8      24BBY    male  Tatooine   Human
# 9      57BBY    male   Stewjon   Human

# %%
df_planets.head(10)
# Out:
#         name  rotation_period  orbital_period  diameter              climate  \
# 0   Alderaan             24.0           364.0   12500.0            temperate
# 1   Yavin IV             24.0          4818.0   10200.0  temperate, tropical
# 2       Hoth             23.0           549.0    7200.0               frozen
# 3    Dagobah             23.0           341.0    8900.0                murky
# 4     Bespin             12.0          5110.0  118000.0            temperate
# 5      Endor             18.0           402.0    4900.0            temperate
# 6      Naboo             26.0           312.0   12120.0            temperate
# 7  Coruscant             24.0           368.0   12240.0            temperate
# 8     Kamino             27.0           463.0   19720.0            temperate
# 9   Geonosis             30.0           256.0   11370.0      temperate, arid
#
#                                   gravity  \
# 0                              1 standard
# 1                              1 standard
# 2                            1.1 standard
# 3                                     NaN
# 4  1.5 (surface), 1 standard (Cloud City)
# 5                           0.85 standard
# 6                              1 standard
# 7                              1 standard
# 8                              1 standard
# 9                            0.9 standard
#
#                                     terrain  surface_water    population
# 0                     grasslands, mountains           40.0  2.000000e+09
# 1                       jungle, rainforests            8.0  1.000000e+03
# 2        tundra, ice caves, mountain ranges          100.0           NaN
# 3                            swamp, jungles            8.0           NaN
# 4                                 gas giant            0.0  6.000000e+06
# 5                 forests, mountains, lakes            8.0  3.000000e+07
# 6  grassy hills, swamps, forests, mountains           12.0  4.500000e+09
# 7                      cityscape, mountains            NaN  1.000000e+12
# 8                                     ocean          100.0  1.000000e+09
# 9            rock, desert, mountain, barren            5.0  1.000000e+11

# %%
df_species.head(10)
# Out:
#              name classification designation  average_height  \
# 0            Hutt      gastropod    sentient           300.0
# 1  Yoda's species         mammal    sentient            66.0
# 2      Trandoshan        reptile    sentient           200.0
# 3    Mon Calamari      amphibian    sentient           160.0
# 4            Ewok         mammal    sentient           100.0
# 5       Sullustan         mammal    sentient           180.0
# 6       Neimodian            NaN    sentient           180.0
# 7          Gungan      amphibian    sentient           190.0
# 8       Toydarian         mammal    sentient           120.0
# 9             Dug         mammal    sentient           100.0
#
#                  skin_colors          hair_colors            eye_colors  \
# 0          green, brown, tan                  NaN           yellow, red
# 1              green, yellow         brown, white  brown, green, yellow
# 2               brown, green                 none        yellow, orange
# 3  red, blue, brown, magenta                 none                yellow
# 4                      brown  white, brown, black         orange, brown
# 5                       pale                 none                 black
# 6                grey, green                 none             red, pink
# 7               brown, green                 none                orange
# 8          blue, green, grey                 none                yellow
# 9   brown, purple, grey, red                 none          yellow, blue
#
#   average_lifespan        language       homeworld
# 0             1000         Huttese       Nal Hutta
# 1              900  Galactic basic             NaN
# 2              NaN            Dosh       Trandosha
# 3              NaN  Mon Calamarian        Mon Cala
# 4              NaN         Ewokese           Endor
# 5              NaN       Sullutese         Sullust
# 6              NaN       Neimoidia  Cato Neimoidia
# 7              NaN    Gungan basic           Naboo
# 8               91       Toydarian        Toydaria
# 9              NaN          Dugese       Malastare

# %%
df_starships.head(10)
# Out:
#                             name                                 model  \
# 0                       Executor       Executor-class star dreadnought
# 1   Sentinel-class landing craft          Sentinel-class landing craft
# 2                     Death Star           DS-1 Orbital Battle Station
# 3              Millennium Falcon               YT-1300 light freighter
# 4                         Y-wing                            BTL Y-wing
# 5                         X-wing                           T-65 X-wing
# 6                TIE Advanced x1           Twin Ion Engine Advanced x1
# 7                        Slave 1  Firespray-31-class patrol and attack
# 8               Imperial shuttle             Lambda-class T-4a shuttle
# 9  EF76 Nebulon-B escort frigate         EF76 Nebulon-B escort frigate
#
#                                         manufacturer  cost_in_credits  length  \
# 0                 Kuat Drive Yards, Fondor Shipyards     1.143350e+09   19000
# 1            Sienar Fleet Systems, Cyngus Spaceworks     2.400000e+05      38
# 2  Imperial Department of Military Research, Sien...     1.000000e+12  120000
# 3                  Corellian Engineering Corporation     1.000000e+05   34.37
# 4                             Koensayr Manufacturing     1.349990e+05      14
# 5                                  Incom Corporation     1.499990e+05    12.5
# 6                               Sienar Fleet Systems              NaN     9.2
# 7                           Kuat Systems Engineering              NaN    21.5
# 8                               Sienar Fleet Systems     2.400000e+05      20
# 9                                   Kuat Drive Yards     8.500000e+06     300
#
#   max_atmosphering_speed      crew  passengers  cargo_capacity consumables  \
# 0                    NaN  279144.0     38000.0    2.500000e+08     6 years
# 1                   1000       5.0        75.0    1.800000e+05     1 month
# 2                    NaN  342953.0    843342.0    1.000000e+12     3 years
# 3                   1050       4.0         6.0    1.000000e+05    2 months
# 4                 1000km       2.0         0.0    1.100000e+02      1 week
# 5                   1050       1.0         0.0    1.100000e+02      1 week
# 6                   1200       1.0         0.0    1.500000e+02      5 days
# 7                   1000       1.0         6.0    7.000000e+04     1 month
# 8                    850       6.0        20.0    8.000000e+04    2 months
# 9                    800     854.0        75.0    6.000000e+06     2 years
#
#    hyperdrive_rating   MGLT                   starship_class
# 0                2.0   40.0                 Star dreadnought
# 1                1.0   70.0                    landing craft
# 2                4.0   10.0  Deep Space Mobile Battlestation
# 3                0.5   75.0                  Light freighter
# 4                1.0   80.0              assault starfighter
# 5                1.0  100.0                      Starfighter
# 6                1.0  105.0                      Starfighter
# 7                3.0   70.0                     Patrol craft
# 8                1.0   50.0       Armed government transport
# 9                2.0   40.0                      Escort ship

# %%
df_vehicles.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer  cost_in_credits  length  \
# 0  Corellia Mining Corporation         150000.0    36.8
# 1            Incom Corporation          14500.0    10.4
# 2         SoroSuub Corporation          10550.0     3.4
# 3         Sienar Fleet Systems              NaN     6.4
# 4            Incom corporation              NaN     4.5
#
#    max_atmosphering_speed  crew  passengers cargo_capacity consumables  \
# 0                    30.0    46        30.0          50000    2 months
# 1                  1200.0     1         1.0             50           0
# 2                   250.0     1         1.0              5         NaN
# 3                  1200.0     1         0.0             65      2 days
# 4                   650.0     2         0.0             10        none
#
#    vehicle_class
# 0        wheeled
# 1  repulsorcraft
# 2  repulsorcraft
# 3    starfighter
# 4     airspeeder

# %%
df_species['language'].unique()
# Out:
# array(['Huttese', 'Galactic basic', 'Dosh', 'Mon Calamarian', 'Ewokese',
#        'Sullutese', 'Neimoidia', 'Gungan basic', 'Toydarian', 'Dugese',
#        "Twi'leki", 'Aleena', 'vulpterish', 'Xextese', 'Tundan', 'Cerean',
#        'Nautila', 'Zabraki', nan, 'Iktotchese', 'Quermian', 'Kel Dor',
#        'Chagria', 'Geonosian', 'Mirialan', 'Clawdite', 'besalisk',
#        'Kaminoan', 'Skakoan', 'Muun', 'Togruti', 'Kaleesh', 'Utapese',
#        'Shyriiwook', 'Galactic Basic'], dtype=object)

# %%
df_planets.head()
# Out:
#        name  rotation_period  orbital_period  diameter              climate  \
# 0  Alderaan             24.0           364.0   12500.0            temperate
# 1  Yavin IV             24.0          4818.0   10200.0  temperate, tropical
# 2      Hoth             23.0           549.0    7200.0               frozen
# 3   Dagobah             23.0           341.0    8900.0                murky
# 4    Bespin             12.0          5110.0  118000.0            temperate
#
#                                   gravity                             terrain  \
# 0                              1 standard               grasslands, mountains
# 1                              1 standard                 jungle, rainforests
# 2                            1.1 standard  tundra, ice caves, mountain ranges
# 3                                     NaN                      swamp, jungles
# 4  1.5 (surface), 1 standard (Cloud City)                           gas giant
#
#    surface_water    population
# 0           40.0  2.000000e+09
# 1            8.0  1.000000e+03
# 2          100.0           NaN
# 3            8.0           NaN
# 4            0.0  6.000000e+06

# %%
df_planets['name'].unique()
# Out:
# array(['Alderaan', 'Yavin IV', 'Hoth', 'Dagobah', 'Bespin', 'Endor',
#        'Naboo', 'Coruscant', 'Kamino', 'Geonosis', 'Utapau', 'Mustafar',
#        'Kashyyyk', 'Polis Massa', 'Mygeeto', 'Felucia', 'Cato Neimoidia',
#        'Saleucami', 'Stewjon', 'Eriadu', 'Corellia', 'Rodia', 'Nal Hutta',
#        'Dantooine', 'Bestine IV', 'Ord Mantell', nan, 'Trandosha',
#        'Socorro', 'Mon Cala', 'Chandrila', 'Sullust', 'Toydaria',
#        'Malastare', 'Dathomir', 'Ryloth', 'Aleen Minor', 'Vulpter',
#        'Troiken', 'Tund', 'Haruun Kal', 'Cerea', 'Glee Anselm',
#        'Iridonia', 'Tholoth', 'Iktotch', 'Quermia', 'Dorin', 'Champala',
#        'Mirial', 'Serenno', 'Concord Dawn', 'Zolan', 'Ojom', 'Skako',
#        'Muunilinst', 'Shili', 'Kalee', 'Umbara', 'Tatooine', 'Jakku'],
#       dtype=object)

# %%
df_planets.dropna(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_planets['name'],
    height=df_planets['rotation_period'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Rotation period for each planet', fontsize=16, pad=15)
plt.ylabel('Rotation period (d)')
plt.xlabel('Planet name')
plt.xticks(rotation=90)
plt.ylim(0, 40)
ax.axhline(y=24, linestyle='dashed', alpha=0.5, color='black')
ax.text(x=-1, y=25, s='Rotation period on Earth', alpha=0.7, color='black');

# %%
df_planets['rotation_period_diff'] = abs(df_planets['rotation_period'] - 24)
df_planets.head()
# Out:
#        name  rotation_period  orbital_period  diameter              climate  \
# 0  Alderaan             24.0           364.0   12500.0            temperate
# 1  Yavin IV             24.0          4818.0   10200.0  temperate, tropical
# 4    Bespin             12.0          5110.0  118000.0            temperate
# 5     Endor             18.0           402.0    4900.0            temperate
# 6     Naboo             26.0           312.0   12120.0            temperate
#
#                                   gravity  \
# 0                              1 standard
# 1                              1 standard
# 4  1.5 (surface), 1 standard (Cloud City)
# 5                           0.85 standard
# 6                              1 standard
#
#                                     terrain  surface_water    population  \
# 0                     grasslands, mountains           40.0  2.000000e+09
# 1                       jungle, rainforests            8.0  1.000000e+03
# 4                                 gas giant            0.0  6.000000e+06
# 5                 forests, mountains, lakes            8.0  3.000000e+07
# 6  grassy hills, swamps, forests, mountains           12.0  4.500000e+09
#
#    rotation_period_diff
# 0                   0.0
# 1                   0.0
# 4                  12.0
# 5                   6.0
# 6                   2.0

# %%
print(max(df_planets['rotation_period_diff']))
# Out:
# 12.0

# %%
print(min(df_planets['rotation_period_diff']))
# Out:
# 0.0

# %%
12/10
# Out:
# 1.2

# %%
print(0.0)
print(1.2*1)
print(1.2*2)
print(1.2*3)
print(1.2*4)
print(1.2*5)
print(1.2*6)
print(1.2*7)
print(1.2*8)
print(1.2*9)
print(1.2*10)
# Out:
# 0.0
# 1.2
# 2.4
# 3.5999999999999996
# 4.8
# 6.0
# 7.199999999999999
# 8.4
# 9.6
# 10.799999999999999
# 12.0

# %%
df_planets['rotation_period_pkt'] = df_planets['rotation_period'].apply(lambda x: 10 if x in range(0, 1.2) else
                                                                       9 if x in range (1.2, 2.4) else
                                                                       8 if x in range (2.4, 3.5999999999999996) else
                                                                       7 if x in range (3.5999999999999996, 4.8) else
                                                                       6 if x in range (4.8, 6.0) else
                                                                       5 if x in range (6.0, 7.199999999999999) else
                                                                       4 if x in range (7.199999999999999, 8.4) else
                                                                       3 if x in range (8.4, 9.6) else
                                                                       2 if x in range (9.6, 10.799999999999999) else
                                                                       1 if x in range (10.799999999999999, 12) )
# Out:
#   File "<ipython-input-99-912b90df0899>", line 10
#     1 if x in range (10.799999999999999, 12))
#                                             ^
# SyntaxError: invalid syntax
