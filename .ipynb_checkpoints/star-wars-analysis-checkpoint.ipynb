# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from math import pi
import matplotlib.colors as mcolors
from scipy import stats

from csv import reader
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
from pathlib import Path
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from pysankey import sankey

from scipy.stats import shapiro
from scipy.stats import ttest_ind
from scipy.stats import f

# Get the data
characters = open('star-wars-dataset/characters.csv')
df_characters = pd.read_csv('star-wars-dataset/characters.csv')
planets = open('star-wars-dataset/planets.csv')
df_planets = pd.read_csv('star-wars-dataset/planets.csv')
species = open('star-wars-dataset/species.csv')
df_species = pd.read_csv('star-wars-dataset/species.csv')
starships = open('star-wars-dataset/starships.csv')
df_starships = pd.read_csv('star-wars-dataset/starships.csv')
vehicles = open('star-wars-dataset/vehicles.csv')
df_vehicles = pd.read_csv('star-wars-dataset/vehicles.csv')


sns.set()

# %%
df_characters.head(10)
# Out:
#                  name  height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker   172.0   77          blond         fair       blue
# 1               C-3PO   167.0   75            NaN         gold     yellow
# 2               R2-D2    96.0   32            NaN  white, blue        red
# 3         Darth Vader   202.0  136           none        white     yellow
# 4         Leia Organa   150.0   49          brown        light      brown
# 5           Owen Lars   178.0  120    brown, grey        light       blue
# 6  Beru Whitesun lars   165.0   75          brown        light       blue
# 7               R5-D4    97.0   32            NaN   white, red        red
# 8   Biggs Darklighter   183.0   84          black        light      brown
# 9      Obi-Wan Kenobi   182.0   77  auburn, white         fair  blue-gray
#
#   birth_year  gender homeworld species
# 0      19BBY    male  Tatooine   Human
# 1     112BBY     NaN  Tatooine   Droid
# 2      33BBY     NaN     Naboo   Droid
# 3    41.9BBY    male  Tatooine   Human
# 4      19BBY  female  Alderaan   Human
# 5      52BBY    male  Tatooine   Human
# 6      47BBY  female  Tatooine   Human
# 7        NaN     NaN  Tatooine   Droid
# 8      24BBY    male  Tatooine   Human
# 9      57BBY    male   Stewjon   Human

# %%
df_planets.head(10)
# Out:
#         name  rotation_period  orbital_period  diameter              climate  \
# 0   Alderaan             24.0           364.0   12500.0            temperate
# 1   Yavin IV             24.0          4818.0   10200.0  temperate, tropical
# 2       Hoth             23.0           549.0    7200.0               frozen
# 3    Dagobah             23.0           341.0    8900.0                murky
# 4     Bespin             12.0          5110.0  118000.0            temperate
# 5      Endor             18.0           402.0    4900.0            temperate
# 6      Naboo             26.0           312.0   12120.0            temperate
# 7  Coruscant             24.0           368.0   12240.0            temperate
# 8     Kamino             27.0           463.0   19720.0            temperate
# 9   Geonosis             30.0           256.0   11370.0      temperate, arid
#
#                                   gravity  \
# 0                              1 standard
# 1                              1 standard
# 2                            1.1 standard
# 3                                     NaN
# 4  1.5 (surface), 1 standard (Cloud City)
# 5                           0.85 standard
# 6                              1 standard
# 7                              1 standard
# 8                              1 standard
# 9                            0.9 standard
#
#                                     terrain  surface_water    population
# 0                     grasslands, mountains           40.0  2.000000e+09
# 1                       jungle, rainforests            8.0  1.000000e+03
# 2        tundra, ice caves, mountain ranges          100.0           NaN
# 3                            swamp, jungles            8.0           NaN
# 4                                 gas giant            0.0  6.000000e+06
# 5                 forests, mountains, lakes            8.0  3.000000e+07
# 6  grassy hills, swamps, forests, mountains           12.0  4.500000e+09
# 7                      cityscape, mountains            NaN  1.000000e+12
# 8                                     ocean          100.0  1.000000e+09
# 9            rock, desert, mountain, barren            5.0  1.000000e+11

# %%
df_species.head(10)
# Out:
#              name classification designation  average_height  \
# 0            Hutt      gastropod    sentient           300.0
# 1  Yoda's species         mammal    sentient            66.0
# 2      Trandoshan        reptile    sentient           200.0
# 3    Mon Calamari      amphibian    sentient           160.0
# 4            Ewok         mammal    sentient           100.0
# 5       Sullustan         mammal    sentient           180.0
# 6       Neimodian            NaN    sentient           180.0
# 7          Gungan      amphibian    sentient           190.0
# 8       Toydarian         mammal    sentient           120.0
# 9             Dug         mammal    sentient           100.0
#
#                  skin_colors          hair_colors            eye_colors  \
# 0          green, brown, tan                  NaN           yellow, red
# 1              green, yellow         brown, white  brown, green, yellow
# 2               brown, green                 none        yellow, orange
# 3  red, blue, brown, magenta                 none                yellow
# 4                      brown  white, brown, black         orange, brown
# 5                       pale                 none                 black
# 6                grey, green                 none             red, pink
# 7               brown, green                 none                orange
# 8          blue, green, grey                 none                yellow
# 9   brown, purple, grey, red                 none          yellow, blue
#
#   average_lifespan        language       homeworld
# 0             1000         Huttese       Nal Hutta
# 1              900  Galactic basic             NaN
# 2              NaN            Dosh       Trandosha
# 3              NaN  Mon Calamarian        Mon Cala
# 4              NaN         Ewokese           Endor
# 5              NaN       Sullutese         Sullust
# 6              NaN       Neimoidia  Cato Neimoidia
# 7              NaN    Gungan basic           Naboo
# 8               91       Toydarian        Toydaria
# 9              NaN          Dugese       Malastare

# %%
df_starships.head(10)
# Out:
#                             name                                 model  \
# 0                       Executor       Executor-class star dreadnought
# 1   Sentinel-class landing craft          Sentinel-class landing craft
# 2                     Death Star           DS-1 Orbital Battle Station
# 3              Millennium Falcon               YT-1300 light freighter
# 4                         Y-wing                            BTL Y-wing
# 5                         X-wing                           T-65 X-wing
# 6                TIE Advanced x1           Twin Ion Engine Advanced x1
# 7                        Slave 1  Firespray-31-class patrol and attack
# 8               Imperial shuttle             Lambda-class T-4a shuttle
# 9  EF76 Nebulon-B escort frigate         EF76 Nebulon-B escort frigate
#
#                                         manufacturer  cost_in_credits  length  \
# 0                 Kuat Drive Yards, Fondor Shipyards     1.143350e+09   19000
# 1            Sienar Fleet Systems, Cyngus Spaceworks     2.400000e+05      38
# 2  Imperial Department of Military Research, Sien...     1.000000e+12  120000
# 3                  Corellian Engineering Corporation     1.000000e+05   34.37
# 4                             Koensayr Manufacturing     1.349990e+05      14
# 5                                  Incom Corporation     1.499990e+05    12.5
# 6                               Sienar Fleet Systems              NaN     9.2
# 7                           Kuat Systems Engineering              NaN    21.5
# 8                               Sienar Fleet Systems     2.400000e+05      20
# 9                                   Kuat Drive Yards     8.500000e+06     300
#
#   max_atmosphering_speed      crew  passengers  cargo_capacity consumables  \
# 0                    NaN  279144.0     38000.0    2.500000e+08     6 years
# 1                   1000       5.0        75.0    1.800000e+05     1 month
# 2                    NaN  342953.0    843342.0    1.000000e+12     3 years
# 3                   1050       4.0         6.0    1.000000e+05    2 months
# 4                 1000km       2.0         0.0    1.100000e+02      1 week
# 5                   1050       1.0         0.0    1.100000e+02      1 week
# 6                   1200       1.0         0.0    1.500000e+02      5 days
# 7                   1000       1.0         6.0    7.000000e+04     1 month
# 8                    850       6.0        20.0    8.000000e+04    2 months
# 9                    800     854.0        75.0    6.000000e+06     2 years
#
#    hyperdrive_rating   MGLT                   starship_class
# 0                2.0   40.0                 Star dreadnought
# 1                1.0   70.0                    landing craft
# 2                4.0   10.0  Deep Space Mobile Battlestation
# 3                0.5   75.0                  Light freighter
# 4                1.0   80.0              assault starfighter
# 5                1.0  100.0                      Starfighter
# 6                1.0  105.0                      Starfighter
# 7                3.0   70.0                     Patrol craft
# 8                1.0   50.0       Armed government transport
# 9                2.0   40.0                      Escort ship

# %%
df_vehicles.head()
# Out:
#                  name                           model  \
# 0        Sand Crawler                  Digger Crawler
# 1      T-16 skyhopper                  T-16 skyhopper
# 2    X-34 landspeeder                X-34 landspeeder
# 3  TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4         Snowspeeder                 t-47 airspeeder
#
#                   manufacturer  cost_in_credits  length  \
# 0  Corellia Mining Corporation         150000.0    36.8
# 1            Incom Corporation          14500.0    10.4
# 2         SoroSuub Corporation          10550.0     3.4
# 3         Sienar Fleet Systems              NaN     6.4
# 4            Incom corporation              NaN     4.5
#
#    max_atmosphering_speed  crew  passengers cargo_capacity consumables  \
# 0                    30.0    46        30.0          50000    2 months
# 1                  1200.0     1         1.0             50           0
# 2                   250.0     1         1.0              5         NaN
# 3                  1200.0     1         0.0             65      2 days
# 4                   650.0     2         0.0             10        none
#
#    vehicle_class
# 0        wheeled
# 1  repulsorcraft
# 2  repulsorcraft
# 3    starfighter
# 4     airspeeder

# %%
df_species['language'].unique()
# Out:
# array(['Huttese', 'Galactic basic', 'Dosh', 'Mon Calamarian', 'Ewokese',
#        'Sullutese', 'Neimoidia', 'Gungan basic', 'Toydarian', 'Dugese',
#        "Twi'leki", 'Aleena', 'vulpterish', 'Xextese', 'Tundan', 'Cerean',
#        'Nautila', 'Zabraki', nan, 'Iktotchese', 'Quermian', 'Kel Dor',
#        'Chagria', 'Geonosian', 'Mirialan', 'Clawdite', 'besalisk',
#        'Kaminoan', 'Skakoan', 'Muun', 'Togruti', 'Kaleesh', 'Utapese',
#        'Shyriiwook', 'Galactic Basic'], dtype=object)

# %% [markdown]
# ## Similarity to Earth analysis

# %%
df_planets.head()
# Out:
#        name  rotation_period  orbital_period  diameter              climate  \
# 0  Alderaan             24.0           364.0   12500.0            temperate
# 1  Yavin IV             24.0          4818.0   10200.0  temperate, tropical
# 2      Hoth             23.0           549.0    7200.0               frozen
# 3   Dagobah             23.0           341.0    8900.0                murky
# 4    Bespin             12.0          5110.0  118000.0            temperate
#
#                                   gravity                             terrain  \
# 0                              1 standard               grasslands, mountains
# 1                              1 standard                 jungle, rainforests
# 2                            1.1 standard  tundra, ice caves, mountain ranges
# 3                                     NaN                      swamp, jungles
# 4  1.5 (surface), 1 standard (Cloud City)                           gas giant
#
#    surface_water    population
# 0           40.0  2.000000e+09
# 1            8.0  1.000000e+03
# 2          100.0           NaN
# 3            8.0           NaN
# 4            0.0  6.000000e+06

# %%
# Sort in alphabetical order by the name of the planets
df_planets = df_planets.sort_values('name', ascending=True)
df_planets.head()
# Out:
#               name  rotation_period  orbital_period  diameter  \
# 0         Alderaan             24.0           364.0   12500.0
# 36     Aleen Minor              NaN             NaN       NaN
# 4           Bespin             12.0          5110.0  118000.0
# 24      Bestine IV             26.0           680.0    6400.0
# 16  Cato Neimoidia             25.0           278.0       0.0
#
#              climate                                 gravity  \
# 0          temperate                              1 standard
# 36               NaN                                     NaN
# 4          temperate  1.5 (surface), 1 standard (Cloud City)
# 24         temperate                                     NaN
# 16  temperate, moist                              1 standard
#
#                                     terrain  surface_water    population
# 0                     grasslands, mountains           40.0  2.000000e+09
# 36                                      NaN            NaN           NaN
# 4                                 gas giant            0.0  6.000000e+06
# 24                    rocky islands, oceans           98.0  6.200000e+07
# 16  mountains, fields, forests, rock arches            NaN  1.000000e+07

# %%
# Reset index of the data frame
df_planets = df_planets.reset_index(drop=True)
df_planets.head()
# Out:
#              name  rotation_period  orbital_period  diameter  \
# 0        Alderaan             24.0           364.0   12500.0
# 1     Aleen Minor              NaN             NaN       NaN
# 2          Bespin             12.0          5110.0  118000.0
# 3      Bestine IV             26.0           680.0    6400.0
# 4  Cato Neimoidia             25.0           278.0       0.0
#
#             climate                                 gravity  \
# 0         temperate                              1 standard
# 1               NaN                                     NaN
# 2         temperate  1.5 (surface), 1 standard (Cloud City)
# 3         temperate                                     NaN
# 4  temperate, moist                              1 standard
#
#                                    terrain  surface_water    population
# 0                    grasslands, mountains           40.0  2.000000e+09
# 1                                      NaN            NaN           NaN
# 2                                gas giant            0.0  6.000000e+06
# 3                    rocky islands, oceans           98.0  6.200000e+07
# 4  mountains, fields, forests, rock arches            NaN  1.000000e+07

# %%
df_planets['name'].unique()
# Out:
# array(['Alderaan', 'Aleen Minor', 'Bespin', 'Bestine IV',
#        'Cato Neimoidia', 'Cerea', 'Champala', 'Chandrila', 'Concord Dawn',
#        'Corellia', 'Coruscant', 'Dagobah', 'Dantooine', 'Dathomir',
#        'Dorin', 'Endor', 'Eriadu', 'Felucia', 'Geonosis', 'Glee Anselm',
#        'Haruun Kal', 'Hoth', 'Iktotch', 'Iridonia', 'Jakku', 'Kalee',
#        'Kamino', 'Kashyyyk', 'Malastare', 'Mirial', 'Mon Cala',
#        'Mustafar', 'Muunilinst', 'Mygeeto', 'Naboo', 'Nal Hutta', 'Ojom',
#        'Ord Mantell', 'Polis Massa', 'Quermia', 'Rodia', 'Ryloth',
#        'Saleucami', 'Serenno', 'Shili', 'Skako', 'Socorro', 'Stewjon',
#        'Sullust', 'Tatooine', 'Tholoth', 'Toydaria', 'Trandosha',
#        'Troiken', 'Tund', 'Umbara', 'Utapau', 'Vulpter', 'Yavin IV',
#        'Zolan', nan], dtype=object)

# %%
df_planets.dropna(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_planets['name'],
    height=df_planets['rotation_period'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Rotation period for each planet', fontsize=16, pad=15)
plt.ylabel('Rotation period (d)')
plt.xlabel('Planet name')
plt.xticks(rotation=90)
plt.ylim(0, 40)
ax.axhline(y=24, linestyle='dashed', alpha=0.5, color='black')
ax.text(x=-1, y=25, s='Rotation period on Earth', alpha=0.7, color='black');

# %%
df_planets['rotation_period_diff'] = abs(df_planets['rotation_period'] - 24)
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff
# 0            40.0  2.000000e+09                   0.0
# 2             0.0  6.000000e+06                  12.0
# 7            40.0  1.200000e+09                   4.0
# 9            70.0  3.000000e+09                   1.0
# 15            8.0  3.000000e+07                   6.0

# %%
#df_planets['rotation_period_diff'] = df_planets['rotation_period_diff'].apply(np.int64) # This works as well, leaving here for a learning purpose
df_planets['rotation_period_diff'] = df_planets['rotation_period_diff'].astype('int64')
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff
# 0            40.0  2.000000e+09                     0
# 2             0.0  6.000000e+06                    12
# 7            40.0  1.200000e+09                     4
# 9            70.0  3.000000e+09                     1
# 15            8.0  3.000000e+07                     6

# %%
df_planets.dtypes
# Out:
# name                     object
# rotation_period         float64
# orbital_period          float64
# diameter                float64
# climate                  object
# gravity                  object
# terrain                  object
# surface_water           float64
# population              float64
# rotation_period_diff      int64
# dtype: object

# %%
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff
# 0            40.0  2.000000e+09                     0
# 2             0.0  6.000000e+06                    12
# 7            40.0  1.200000e+09                     4
# 9            70.0  3.000000e+09                     1
# 15            8.0  3.000000e+07                     6

# %%
print(min(df_planets['rotation_period_diff']))
# Out:
# 0

# %%
12/10
# Out:
# 1.2

# %%
df_planets.dtypes
# Out:
# name                     object
# rotation_period         float64
# orbital_period          float64
# diameter                float64
# climate                  object
# gravity                  object
# terrain                  object
# surface_water           float64
# population              float64
# rotation_period_diff      int64
# dtype: object

# %%
print(0.0)
print(1.2*1)
print(1.2*2)
print(1.2*3)
print(1.2*4)
print(1.2*5)
print(1.2*6)
print(1.2*7)
print(1.2*8)
print(1.2*9)
print(1.2*10)
# Out:
# 0.0
# 1.2
# 2.4
# 3.5999999999999996
# 4.8
# 6.0
# 7.199999999999999
# 8.4
# 9.6
# 10.799999999999999
# 12.0

# %%
df_planets['rotation_period_diff'].unique()
# Out:
# array([ 0, 12,  4,  1,  6,  9,  3,  2,  5])

# %%
df_planets['rotation_period_pkt'] = df_planets['rotation_period_diff'].apply(lambda x: 10 if x in (0,1) else
                                                                       9 if x == 2 else
                                                                       8 if x == 3 else
                                                                       7 if x == 4 else
                                                                       6 if x == 5 else
                                                                       5 if x == 6 else
                                                                       3 if x == 9 else
                                                                       1)

# %%
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff  rotation_period_pkt
# 0            40.0  2.000000e+09                     0                   10
# 2             0.0  6.000000e+06                    12                    1
# 7            40.0  1.200000e+09                     4                    7
# 9            70.0  3.000000e+09                     1                   10
# 15            8.0  3.000000e+07                     6                    5

# %%
df_planets['rotation_period_pkt'].unique()
# Out:
# array([10,  1,  7,  5,  3,  8,  9,  6])

# %%
print(max(df_planets['orbital_period']))
# Out:
# 5110.0

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_planets['name'],
    height=df_planets['orbital_period'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Orbital period for each planet', fontsize=16, pad=15)
plt.ylabel('Orbital period (d)')
plt.xlabel('Planet name')
plt.xticks(rotation=90)
plt.ylim(0, 5200)
ax.axhline(y=365, linestyle='dashed', alpha=0.5, color='black')
ax.text(x=18, y=600, s='Orbital period on Earth', alpha=0.7, color='black');

# %%
df_planets['orbital_period_diff'] = abs(df_planets['orbital_period'] - 365)
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff  rotation_period_pkt  \
# 0            40.0  2.000000e+09                     0                   10
# 2             0.0  6.000000e+06                    12                    1
# 7            40.0  1.200000e+09                     4                    7
# 9            70.0  3.000000e+09                     1                   10
# 15            8.0  3.000000e+07                     6                    5
#
#     orbital_period_diff
# 0                   1.0
# 2                4745.0
# 7                   3.0
# 9                  36.0
# 15                 37.0

# %%
df_planets['orbital_period_diff'].unique()
# Out:
# array([1.000e+00, 4.745e+03, 3.000e+00, 3.600e+01, 3.700e+01, 1.090e+02,
#        1.590e+02, 9.800e+01, 1.600e+01, 3.300e+01, 4.700e+01, 5.300e+01,
#        3.100e+01, 2.250e+02, 6.000e+01, 1.020e+02, 6.100e+01, 1.400e+01,
#        4.453e+03])

# %%
df_planets.dtypes
# Out:
# name                     object
# rotation_period         float64
# orbital_period          float64
# diameter                float64
# climate                  object
# gravity                  object
# terrain                  object
# surface_water           float64
# population              float64
# rotation_period_diff      int64
# rotation_period_pkt       int64
# orbital_period_diff     float64
# dtype: object

# %%
#df_planets['orbital_period_pkt'] = df_planets['orbital_period_diff'].apply(lambda x: )

# %%
print(max(df_planets['diameter']))
# Out:
# 118000.0

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_planets['name'],
    height=df_planets['diameter'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Orbital period for each planet', fontsize=16, pad=15)
plt.ylabel('Orbital period (d)')
plt.xlabel('Planet name')
plt.xticks(rotation=90)
plt.ylim(0, 120000)
ax.axhline(y=12742, linestyle='dashed', alpha=0.5, color='black')
ax.text(x=18, y=18000, s='Orbital period on Earth', alpha=0.7, color='black');

# %%
df_planets['diameter_diff'] = abs(df_planets['diameter'] - 12742)
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff  rotation_period_pkt  \
# 0            40.0  2.000000e+09                     0                   10
# 2             0.0  6.000000e+06                    12                    1
# 7            40.0  1.200000e+09                     4                    7
# 9            70.0  3.000000e+09                     1                   10
# 15            8.0  3.000000e+07                     6                    5
#
#     orbital_period_diff  diameter_diff
# 0                   1.0          242.0
# 2                4745.0       105258.0
# 7                   3.0          758.0
# 9                  36.0         1742.0
# 15                 37.0         7842.0

# %%
df_planets['diameter_diff'].unique()
# Out:
# array([2.42000e+02, 1.05258e+05, 7.58000e+02, 1.74200e+03, 7.84200e+03,
#        1.37200e+03, 2.85800e+03, 6.97800e+03, 2.30000e+01, 1.71200e+03,
#        8.54200e+03, 1.05800e+03, 6.22000e+02, 1.30800e+03, 1.27420e+04,
#        5.19300e+03, 2.14200e+03, 3.80000e+01, 2.27700e+03, 1.58000e+02,
#        2.54200e+03])

# %%
print(max(df_planets['surface_water']))
# Out:
# 100.0

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_planets['name'],
    height=df_planets['surface_water'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Water surface for each planet', fontsize=16, pad=15)
plt.ylabel('Water surface (%)')
plt.xlabel('Planet name')
plt.xticks(rotation=90)
plt.ylim(0, 100)
ax.axhline(y=71, linestyle='dashed', alpha=0.5, color='black')
ax.text(x=18, y=75, s='Water surface of Earth', alpha=0.7, color='black');

# %%
df_planets['surface_water_diff'] = abs(df_planets['surface_water'] - 71)
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff  rotation_period_pkt  \
# 0            40.0  2.000000e+09                     0                   10
# 2             0.0  6.000000e+06                    12                    1
# 7            40.0  1.200000e+09                     4                    7
# 9            70.0  3.000000e+09                     1                   10
# 15            8.0  3.000000e+07                     6                    5
#
#     orbital_period_diff  diameter_diff  surface_water_diff
# 0                   1.0          242.0                31.0
# 2                4745.0       105258.0                71.0
# 7                   3.0          758.0                31.0
# 9                  36.0         1742.0                 1.0
# 15                 37.0         7842.0                63.0

# %%
df_planets['surface_water_diff'].unique()
# Out:
# array([31. , 71. ,  1. , 63. , 66. ,  9. , 29. , 11. , 46. , 59. , 61. ,
#        70. , 70.1])

# %%
print(max(df_planets['population']))
# Out:
# 100000000000.0

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_planets['name'],
    height=df_planets['population'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Population for each planet', fontsize=16, pad=15)
plt.ylabel('Population (#)')
plt.xlabel('Planet name')
plt.xticks(rotation=90)
plt.ylim(0, 100000000000)
ax.axhline(y=7700000000, linestyle='dashed', alpha=0.5, color='black')
ax.text(x=18, y=10000000000, s='Population of Earth', alpha=0.7, color='black');

# %%
df_planets['population_diff'] = abs(df_planets['population'] - 7700000000)
df_planets.head()
# Out:
#          name  rotation_period  orbital_period  diameter    climate  \
# 0    Alderaan             24.0           364.0   12500.0  temperate
# 2      Bespin             12.0          5110.0  118000.0  temperate
# 7   Chandrila             20.0           368.0   13500.0  temperate
# 9    Corellia             25.0           329.0   11000.0  temperate
# 15      Endor             18.0           402.0    4900.0  temperate
#
#                                    gravity                        terrain  \
# 0                               1 standard          grasslands, mountains
# 2   1.5 (surface), 1 standard (Cloud City)                      gas giant
# 7                                        1                plains, forests
# 9                               1 standard  plains, urban, hills, forests
# 15                           0.85 standard      forests, mountains, lakes
#
#     surface_water    population  rotation_period_diff  rotation_period_pkt  \
# 0            40.0  2.000000e+09                     0                   10
# 2             0.0  6.000000e+06                    12                    1
# 7            40.0  1.200000e+09                     4                    7
# 9            70.0  3.000000e+09                     1                   10
# 15            8.0  3.000000e+07                     6                    5
#
#     orbital_period_diff  diameter_diff  surface_water_diff  population_diff
# 0                   1.0          242.0                31.0     5.700000e+09
# 2                4745.0       105258.0                71.0     7.694000e+09
# 7                   3.0          758.0                31.0     6.500000e+09
# 9                  36.0         1742.0                 1.0     4.700000e+09
# 15                 37.0         7842.0                63.0     7.670000e+09

# %%
df_planets['gravity'].unique()
# Out:
# array(['1 standard', '1.5 (surface), 1 standard (Cloud City)', '1',
#        '0.85 standard', '0.9 standard', '0.56 standard'], dtype=object)

# %%
df_planets['gravity'] = df_planets['gravity'].apply(lambda x: '1' if '1 standard' == x else
                                                   '1' if '1' == x else
                                                   '1.5' if '1.5 (surface), 1 standard (Cloud City)' == x else
                                                   '0.85' if '0.85 standard' == x else
                                                   '0.9' if '0.9 standard' == x else
                                                   '0.56' if '0.56 standard' == x else
                                                   '0')

# %%
df_planets.dtypes
# Out:
# name                     object
# rotation_period         float64
# orbital_period          float64
# diameter                float64
# climate                  object
# gravity                  object
# terrain                  object
# surface_water           float64
# population              float64
# rotation_period_diff      int64
# rotation_period_pkt       int64
# orbital_period_diff     float64
# diameter_diff           float64
# surface_water_diff      float64
# population_diff         float64
# dtype: object

# %%
#df_planets['gravity'].astype(str).astype(int)

# %%
df_planets.dtypes
# Out:
# name                     object
# rotation_period         float64
# orbital_period          float64
# diameter                float64
# climate                  object
# gravity                  object
# terrain                  object
# surface_water           float64
# population              float64
# rotation_period_diff      int64
# rotation_period_pkt       int64
# orbital_period_diff     float64
# diameter_diff           float64
# surface_water_diff      float64
# population_diff         float64
# dtype: object

# %%
df_planets['gravity'].unique
# Out:
# <bound method Series.unique of 0        1
# 2      1.5
# 7        1
# 9        1
# 15    0.85
# 18     0.9
# 19       1
# 26       1
# 27       1
# 30       1
# 31       1
# 32       1
# 34       1
# 37       1
# 38    0.56
# 40       1
# 41       1
# 48       1
# 49       1
# 56       1
# 58       1
# Name: gravity, dtype: object>

# %% [markdown]
# ## The most common color of eyes/hair

# %%
# Show the data frame
df_species.head(38)
# Out:
#               name classification designation  average_height  \
# 0             Hutt      gastropod    sentient           300.0
# 1   Yoda's species         mammal    sentient            66.0
# 2       Trandoshan        reptile    sentient           200.0
# 3     Mon Calamari      amphibian    sentient           160.0
# 4             Ewok         mammal    sentient           100.0
# 5        Sullustan         mammal    sentient           180.0
# 6        Neimodian            NaN    sentient           180.0
# 7           Gungan      amphibian    sentient           190.0
# 8        Toydarian         mammal    sentient           120.0
# 9              Dug         mammal    sentient           100.0
# 10         Twi'lek        mammals    sentient           200.0
# 11          Aleena        reptile    sentient            80.0
# 12      Vulptereen            NaN    sentient           100.0
# 13           Xexto            NaN    sentient           125.0
# 14           Toong            NaN    sentient           200.0
# 15          Cerean         mammal    sentient           200.0
# 16        Nautolan      amphibian    sentient           180.0
# 17          Zabrak         mammal    sentient           180.0
# 18      Tholothian         mammal    sentient             NaN
# 19        Iktotchi            NaN    sentient           180.0
# 20        Quermian         mammal    sentient           240.0
# 21         Kel Dor            NaN    sentient           180.0
# 22        Chagrian      amphibian    sentient           190.0
# 23       Geonosian      insectoid    sentient           178.0
# 24        Mirialan         mammal    sentient           180.0
# 25        Clawdite      reptilian    sentient           180.0
# 26        Besalisk      amphibian    sentient           178.0
# 27        Kaminoan      amphibian    sentient           220.0
# 28         Skakoan         mammal    sentient             NaN
# 29            Muun         mammal    sentient           190.0
# 30         Togruta         mammal    sentient           180.0
# 31         Kaleesh        reptile    sentient           170.0
# 32          Pau'an         mammal    sentient           190.0
# 33         Wookiee         mammal    sentient           210.0
# 34           Droid     artificial    sentient             NaN
# 35           Human         mammal    sentient           180.0
# 36          Rodian       sentient   reptilian           170.0
#
#                                        skin_colors                hair_colors  \
# 0                                green, brown, tan                        NaN
# 1                                    green, yellow               brown, white
# 2                                     brown, green                       none
# 3                        red, blue, brown, magenta                       none
# 4                                            brown        white, brown, black
# 5                                             pale                       none
# 6                                      grey, green                       none
# 7                                     brown, green                       none
# 8                                blue, green, grey                       none
# 9                         brown, purple, grey, red                       none
# 10  orange, yellow, blue, green, pink, purple, tan                       none
# 11                                      blue, gray                       none
# 12                                            grey                       none
# 13                            grey, yellow, purple                       none
# 14                             grey, green, yellow                       none
# 15                                       pale pink   red, blond, black, white
# 16                         green, blue, brown, red                       none
# 17                pale, brown, red, orange, yellow                      black
# 18                                            dark                        NaN
# 19                                            pink                       none
# 20                                           white                       none
# 21                              peach, orange, red                       none
# 22                                            blue                       none
# 23                                    green, brown                       none
# 24                                   yellow, green               black, brown
# 25                                   green, yellow                       none
# 26                                           brown                       none
# 27                                      grey, blue                       none
# 28                                     grey, green                       none
# 29                                     grey, white                       none
# 30         red, white, orange, yellow, green, blue                       none
# 31                              brown, orange, tan                       none
# 32                                            grey                       none
# 33                                            gray               black, brown
# 34                                             NaN                        NaN
# 35               caucasian, black, asian, hispanic  blonde, brown, black, red
# 36                                     green, blue                        NaN
#
#                                  eye_colors average_lifespan        language  \
# 0                               yellow, red             1000         Huttese
# 1                      brown, green, yellow              900  Galactic basic
# 2                            yellow, orange              NaN            Dosh
# 3                                    yellow              NaN  Mon Calamarian
# 4                             orange, brown              NaN         Ewokese
# 5                                     black              NaN       Sullutese
# 6                                 red, pink              NaN       Neimoidia
# 7                                    orange              NaN    Gungan basic
# 8                                    yellow               91       Toydarian
# 9                              yellow, blue              NaN          Dugese
# 10                blue, brown, orange, pink              NaN        Twi'leki
# 11                                      NaN               79          Aleena
# 12                                   yellow              NaN      vulpterish
# 13                                    black              NaN         Xextese
# 14                                   orange              NaN          Tundan
# 15                                    hazel              NaN          Cerean
# 16                                    black               70         Nautila
# 17                            brown, orange              NaN         Zabraki
# 18                             blue, indigo              NaN             NaN
# 19                                   orange              NaN      Iktotchese
# 20                                   yellow               86        Quermian
# 21                            black, silver               70         Kel Dor
# 22                                     blue              NaN         Chagria
# 23                             green, hazel              NaN       Geonosian
# 24  blue, green, red, yellow, brown, orange              NaN        Mirialan
# 25                                   yellow               70        Clawdite
# 26                                   yellow               75        besalisk
# 27                                    black               80        Kaminoan
# 28                                      NaN              NaN         Skakoan
# 29                                    black              100            Muun
# 30  red, orange, yellow, green, blue, black               94         Togruti
# 31                                   yellow               80         Kaleesh
# 32                                    black              700         Utapese
# 33  blue, green, yellow, brown, golden, red              400      Shyriiwook
# 34                                      NaN       indefinite             NaN
# 35   brown, blue, green, hazel, grey, amber              120  Galactic Basic
# 36                                    black              NaN  Galactic Basic
#
#          homeworld
# 0        Nal Hutta
# 1              NaN
# 2        Trandosha
# 3         Mon Cala
# 4            Endor
# 5          Sullust
# 6   Cato Neimoidia
# 7            Naboo
# 8         Toydaria
# 9        Malastare
# 10          Ryloth
# 11     Aleen Minor
# 12         Vulpter
# 13         Troiken
# 14            Tund
# 15           Cerea
# 16     Glee Anselm
# 17        Iridonia
# 18         Tholoth
# 19         Iktotch
# 20         Quermia
# 21           Dorin
# 22        Champala
# 23        Geonosis
# 24          Mirial
# 25           Zolan
# 26            Ojom
# 27          Kamino
# 28           Skako
# 29      Muunilinst
# 30           Shili
# 31           Kalee
# 32          Utapau
# 33        Kashyyyk
# 34             NaN
# 35       Coruscant
# 36           Rodia

# %%
# Check size of the data frame
df_species.shape
# Out:
# (37, 10)

# %% [markdown]
# ### Hair type

# %%
# Show values for hair color
df_species['hair_colors'].unique()
# Out:
# array([nan, 'brown, white', 'none', 'white, brown, black',
#        'red, blond, black, white', 'black', 'black, brown',
#        'blonde, brown, black, red'], dtype=object)

# %%
df_species['hair_colors'].nunique()
# Out:
# 7

# %%
df_species['hair_colors'].value_counts()
# Out:
# none                         26
# black, brown                  2
# blonde, brown, black, red     1
# red, blond, black, white      1
# white, brown, black           1
# brown, white                  1
# black                         1
# Name: hair_colors, dtype: int64

# %%
# Clean unique list
hair_colors_list = df_species['hair_colors'].unique()
hair_colors_list = [x for x in hair_colors_list if str(x) != 'nan']
print(hair_colors_list)
# Out:
# ['brown, white', 'none', 'white, brown, black', 'red, blond, black, white', 'black', 'black, brown', 'blonde, brown, black, red']

# %%
# Split colors
hair_colors_list_splitted = []
for color in hair_colors_list:
    hair_colors_list_splitted.extend(color.split(', '))
print(hair_colors_list_splitted)
# Out:
# ['brown', 'white', 'none', 'white', 'brown', 'black', 'red', 'blond', 'black', 'white', 'black', 'black', 'brown', 'blonde', 'brown', 'black', 'red']

# %%
# Rename list
hair_colors_list = hair_colors_list_splitted

# %%
# Get unique colors only
hair_colors_list = list(set(hair_colors_list))
print(hair_colors_list)
# Out:
# ['black', 'white', 'none', 'blond', 'brown', 'blonde', 'red']

# %%
# Get the number of hair colors in races (exp. yellow color can be in 3 races)
for each_color in hair_colors_list:
    print(each_color, df_species.hair_colors.str.count(each_color).sum())
# Out:
# black 6.0
# white 3.0
# none 26.0
# blond 2.0
# brown 5.0
# blonde 1.0
# red 2.0

# %%
# Bar chart with the number of species with particular color of hair
value = [3, 1, 2, 6, 2, 26, 5]
index = ['white', 'blonde', 'blond', 'black', 'red', 'none', 'brown']
df_hair = pd.DataFrame({'species_number': value, 'hair': index}).sort_values(by='species_number', ascending=False)
df_hair.head()
# Out:
#    species_number   hair
# 5              26   none
# 3               6  black
# 6               5  brown
# 0               3  white
# 2               2  blond

# %%
# Plot bar chart
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_hair['hair'],
    height=df_hair['species_number'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Number of species by hair type', fontsize=16, pad=15)
plt.ylabel('Number of species')
plt.xlabel('Hair type')
plt.xticks(rotation=90)
plt.ylim(0, 30)
# Out:
# (0, 30)

# %% [markdown]
# #TODO:
# * Change the font sizes
# * Check if there is a difference between `blond` and `blonde`

# %% [markdown]
# ### Eyes color

# %%
df_species.head(38)
# Out:
#               name classification designation  average_height  \
# 0             Hutt      gastropod    sentient           300.0
# 1   Yoda's species         mammal    sentient            66.0
# 2       Trandoshan        reptile    sentient           200.0
# 3     Mon Calamari      amphibian    sentient           160.0
# 4             Ewok         mammal    sentient           100.0
# 5        Sullustan         mammal    sentient           180.0
# 6        Neimodian            NaN    sentient           180.0
# 7           Gungan      amphibian    sentient           190.0
# 8        Toydarian         mammal    sentient           120.0
# 9              Dug         mammal    sentient           100.0
# 10         Twi'lek        mammals    sentient           200.0
# 11          Aleena        reptile    sentient            80.0
# 12      Vulptereen            NaN    sentient           100.0
# 13           Xexto            NaN    sentient           125.0
# 14           Toong            NaN    sentient           200.0
# 15          Cerean         mammal    sentient           200.0
# 16        Nautolan      amphibian    sentient           180.0
# 17          Zabrak         mammal    sentient           180.0
# 18      Tholothian         mammal    sentient             NaN
# 19        Iktotchi            NaN    sentient           180.0
# 20        Quermian         mammal    sentient           240.0
# 21         Kel Dor            NaN    sentient           180.0
# 22        Chagrian      amphibian    sentient           190.0
# 23       Geonosian      insectoid    sentient           178.0
# 24        Mirialan         mammal    sentient           180.0
# 25        Clawdite      reptilian    sentient           180.0
# 26        Besalisk      amphibian    sentient           178.0
# 27        Kaminoan      amphibian    sentient           220.0
# 28         Skakoan         mammal    sentient             NaN
# 29            Muun         mammal    sentient           190.0
# 30         Togruta         mammal    sentient           180.0
# 31         Kaleesh        reptile    sentient           170.0
# 32          Pau'an         mammal    sentient           190.0
# 33         Wookiee         mammal    sentient           210.0
# 34           Droid     artificial    sentient             NaN
# 35           Human         mammal    sentient           180.0
# 36          Rodian       sentient   reptilian           170.0
#
#                                        skin_colors                hair_colors  \
# 0                                green, brown, tan                        NaN
# 1                                    green, yellow               brown, white
# 2                                     brown, green                       none
# 3                        red, blue, brown, magenta                       none
# 4                                            brown        white, brown, black
# 5                                             pale                       none
# 6                                      grey, green                       none
# 7                                     brown, green                       none
# 8                                blue, green, grey                       none
# 9                         brown, purple, grey, red                       none
# 10  orange, yellow, blue, green, pink, purple, tan                       none
# 11                                      blue, gray                       none
# 12                                            grey                       none
# 13                            grey, yellow, purple                       none
# 14                             grey, green, yellow                       none
# 15                                       pale pink   red, blond, black, white
# 16                         green, blue, brown, red                       none
# 17                pale, brown, red, orange, yellow                      black
# 18                                            dark                        NaN
# 19                                            pink                       none
# 20                                           white                       none
# 21                              peach, orange, red                       none
# 22                                            blue                       none
# 23                                    green, brown                       none
# 24                                   yellow, green               black, brown
# 25                                   green, yellow                       none
# 26                                           brown                       none
# 27                                      grey, blue                       none
# 28                                     grey, green                       none
# 29                                     grey, white                       none
# 30         red, white, orange, yellow, green, blue                       none
# 31                              brown, orange, tan                       none
# 32                                            grey                       none
# 33                                            gray               black, brown
# 34                                             NaN                        NaN
# 35               caucasian, black, asian, hispanic  blonde, brown, black, red
# 36                                     green, blue                        NaN
#
#                                  eye_colors average_lifespan        language  \
# 0                               yellow, red             1000         Huttese
# 1                      brown, green, yellow              900  Galactic basic
# 2                            yellow, orange              NaN            Dosh
# 3                                    yellow              NaN  Mon Calamarian
# 4                             orange, brown              NaN         Ewokese
# 5                                     black              NaN       Sullutese
# 6                                 red, pink              NaN       Neimoidia
# 7                                    orange              NaN    Gungan basic
# 8                                    yellow               91       Toydarian
# 9                              yellow, blue              NaN          Dugese
# 10                blue, brown, orange, pink              NaN        Twi'leki
# 11                                      NaN               79          Aleena
# 12                                   yellow              NaN      vulpterish
# 13                                    black              NaN         Xextese
# 14                                   orange              NaN          Tundan
# 15                                    hazel              NaN          Cerean
# 16                                    black               70         Nautila
# 17                            brown, orange              NaN         Zabraki
# 18                             blue, indigo              NaN             NaN
# 19                                   orange              NaN      Iktotchese
# 20                                   yellow               86        Quermian
# 21                            black, silver               70         Kel Dor
# 22                                     blue              NaN         Chagria
# 23                             green, hazel              NaN       Geonosian
# 24  blue, green, red, yellow, brown, orange              NaN        Mirialan
# 25                                   yellow               70        Clawdite
# 26                                   yellow               75        besalisk
# 27                                    black               80        Kaminoan
# 28                                      NaN              NaN         Skakoan
# 29                                    black              100            Muun
# 30  red, orange, yellow, green, blue, black               94         Togruti
# 31                                   yellow               80         Kaleesh
# 32                                    black              700         Utapese
# 33  blue, green, yellow, brown, golden, red              400      Shyriiwook
# 34                                      NaN       indefinite             NaN
# 35   brown, blue, green, hazel, grey, amber              120  Galactic Basic
# 36                                    black              NaN  Galactic Basic
#
#          homeworld
# 0        Nal Hutta
# 1              NaN
# 2        Trandosha
# 3         Mon Cala
# 4            Endor
# 5          Sullust
# 6   Cato Neimoidia
# 7            Naboo
# 8         Toydaria
# 9        Malastare
# 10          Ryloth
# 11     Aleen Minor
# 12         Vulpter
# 13         Troiken
# 14            Tund
# 15           Cerea
# 16     Glee Anselm
# 17        Iridonia
# 18         Tholoth
# 19         Iktotch
# 20         Quermia
# 21           Dorin
# 22        Champala
# 23        Geonosis
# 24          Mirial
# 25           Zolan
# 26            Ojom
# 27          Kamino
# 28           Skako
# 29      Muunilinst
# 30           Shili
# 31           Kalee
# 32          Utapau
# 33        Kashyyyk
# 34             NaN
# 35       Coruscant
# 36           Rodia

# %%
# Show values for hair color
df_species['eye_colors'].unique()
# Out:
# ['yellow, red' 'brown, green, yellow' 'yellow, orange' 'yellow'
#  'orange, brown' 'black' 'red, pink' 'orange' 'yellow, blue'
#  'blue, brown, orange, pink' nan 'hazel' 'brown, orange' 'blue, indigo'
#  'black, silver' 'blue' 'green, hazel'
#  'blue, green, red, yellow, brown, orange'
#  'red, orange, yellow, green, blue, black'
#  'blue, green, yellow, brown, golden, red'
#  'brown, blue, green, hazel, grey, amber']

# %%
# Clean unique list
eye_colors_list = df_species['eye_colors'].unique()
eye_colors_list = [x for x in eye_colors_list if str(x) != 'nan']
print(eye_colors_list)
# Out:
# ['yellow, red', 'brown, green, yellow', 'yellow, orange', 'yellow', 'orange, brown', 'black', 'red, pink', 'orange', 'yellow, blue', 'blue, brown, orange, pink', 'hazel', 'brown, orange', 'blue, indigo', 'black, silver', 'blue', 'green, hazel', 'blue, green, red, yellow, brown, orange', 'red, orange, yellow, green, blue, black', 'blue, green, yellow, brown, golden, red', 'brown, blue, green, hazel, grey, amber']

# %%
# Split colors
eye_colors_list_splitted = []
for eye_color in eye_colors_list:
    eye_colors_list_splitted.extend(eye_color.split(', '))
print(eye_colors_list_splitted)
# Out:
# ['yellow', 'red', 'brown', 'green', 'yellow', 'yellow', 'orange', 'yellow', 'orange', 'brown', 'black', 'red', 'pink', 'orange', 'yellow', 'blue', 'blue', 'brown', 'orange', 'pink', 'hazel', 'brown', 'orange', 'blue', 'indigo', 'black', 'silver', 'blue', 'green', 'hazel', 'blue', 'green', 'red', 'yellow', 'brown', 'orange', 'red', 'orange', 'yellow', 'green', 'blue', 'black', 'blue', 'green', 'yellow', 'brown', 'golden', 'red', 'brown', 'blue', 'green', 'hazel', 'grey', 'amber']

# %%
# Rename list
eye_colors_list = eye_colors_list_splitted

# %%
# Get unique colors only
eye_colors_list = list(set(eye_colors_list))
print(eye_colors_list)
# Out:
# ['orange', 'black', 'blue', 'grey', 'amber', 'pink', 'brown', 'silver', 'indigo', 'yellow', 'green', 'red', 'hazel', 'golden']

# %%
# Get the number of eye colors in races (exp. brown color can be in 3 races)
for each_eye_color in eye_colors_list:
    print(each_eye_color, df_species.eye_colors.str.count(each_eye_color).sum())
# Out:
# orange 9.0
# black 9.0
# blue 8.0
# grey 1.0
# amber 1.0
# pink 2.0
# brown 7.0
# silver 1.0
# indigo 1.0
# yellow 14.0
# green 6.0
# red 5.0
# hazel 3.0
# golden 1.0

# %%
# Bar chart with the number of species with particular color of eyes
species_number = [9, 9, 8, 1, 1, 2, 7, 1, 1, 14, 6, 5, 3, 1]
eye_color = ['orange', 'black', 'blue', 'grey', 'amber', 'pink', 'brown', 'silver', 'indigo', 'yellow', 'green', 'red', 'hazel', 'golden']
df_eyes = pd.DataFrame({'species_number': species_number, 'eye_color': eye_color}).sort_values(by='species_number', ascending=False)
df_eyes = df_eyes.reset_index(drop=True)
df_eyes.head()
# Out:
#    species_number eye_color
# 0              14    yellow
# 1               9    orange
# 2               9     black
# 3               8      blue
# 4               7     brown

# %%
# Plot bar chart
fig, ax = plt.subplots(figsize=(15,5))

plt.bar(
    x=df_eyes['eye_color'],
    height=df_eyes['species_number'],
    color=['#00D6D6', '#b74722'],
)
plt.title('Number of species by eye color', fontsize=16, pad=15)
plt.ylabel('Number of species')
plt.xlabel('Eye color')
plt.xticks(rotation=90)
plt.ylim(0, 30)
# Out:
# (0, 30)

# %% [markdown]
# ## Similarity in distribution of certain eyes/hair color for characters in races to distribution for humans

# %% [markdown]
# ## Distribution of races in each world

# %%
df_species.head(10)
# Out:
#              name classification designation  average_height  \
# 0            Hutt      gastropod    sentient           300.0
# 1  Yoda's species         mammal    sentient            66.0
# 2      Trandoshan        reptile    sentient           200.0
# 3    Mon Calamari      amphibian    sentient           160.0
# 4            Ewok         mammal    sentient           100.0
# 5       Sullustan         mammal    sentient           180.0
# 6       Neimodian            NaN    sentient           180.0
# 7          Gungan      amphibian    sentient           190.0
# 8       Toydarian         mammal    sentient           120.0
# 9             Dug         mammal    sentient           100.0
#
#                  skin_colors          hair_colors            eye_colors  \
# 0          green, brown, tan                  NaN           yellow, red
# 1              green, yellow         brown, white  brown, green, yellow
# 2               brown, green                 none        yellow, orange
# 3  red, blue, brown, magenta                 none                yellow
# 4                      brown  white, brown, black         orange, brown
# 5                       pale                 none                 black
# 6                grey, green                 none             red, pink
# 7               brown, green                 none                orange
# 8          blue, green, grey                 none                yellow
# 9   brown, purple, grey, red                 none          yellow, blue
#
#   average_lifespan        language       homeworld
# 0             1000         Huttese       Nal Hutta
# 1              900  Galactic basic             NaN
# 2              NaN            Dosh       Trandosha
# 3              NaN  Mon Calamarian        Mon Cala
# 4              NaN         Ewokese           Endor
# 5              NaN       Sullutese         Sullust
# 6              NaN       Neimoidia  Cato Neimoidia
# 7              NaN    Gungan basic           Naboo
# 8               91       Toydarian        Toydaria
# 9              NaN          Dugese       Malastare

# %%
df_species['name'].nunique()
# Out:
# 37

# %%
df_species['homeworld'].nunique()
# Out:
# 35

# %%
df_species.groupby(['name', 'homeworld']).sum()
# Out:
#                              average_height
# name         homeworld
# Aleena       Aleen Minor               80.0
# Besalisk     Ojom                     178.0
# Cerean       Cerea                    200.0
# Chagrian     Champala                 190.0
# Clawdite     Zolan                    180.0
# Dug          Malastare                100.0
# Ewok         Endor                    100.0
# Geonosian    Geonosis                 178.0
# Gungan       Naboo                    190.0
# Human        Coruscant                180.0
# Hutt         Nal Hutta                300.0
# Iktotchi     Iktotch                  180.0
# Kaleesh      Kalee                    170.0
# Kaminoan     Kamino                   220.0
# Kel Dor      Dorin                    180.0
# Mirialan     Mirial                   180.0
# Mon Calamari Mon Cala                 160.0
# Muun         Muunilinst               190.0
# Nautolan     Glee Anselm              180.0
# Neimodian    Cato Neimoidia           180.0
# Pau'an       Utapau                   190.0
# Quermian     Quermia                  240.0
# Rodian       Rodia                    170.0
# Skakoan      Skako                      0.0
# Sullustan    Sullust                  180.0
# Tholothian   Tholoth                    0.0
# Togruta      Shili                    180.0
# Toong        Tund                     200.0
# Toydarian    Toydaria                 120.0
# Trandoshan   Trandosha                200.0
# Twi'lek      Ryloth                   200.0
# Vulptereen   Vulpter                  100.0
# Wookiee      Kashyyyk                 210.0
# Xexto        Troiken                  125.0
# Zabrak       Iridonia                 180.0

# %% [markdown]
# ## Starships

# %%
df_starships.head(38)
# Out:
#                              name                                     model  \
# 0                        Executor           Executor-class star dreadnought
# 1    Sentinel-class landing craft              Sentinel-class landing craft
# 2                      Death Star               DS-1 Orbital Battle Station
# 3               Millennium Falcon                   YT-1300 light freighter
# 4                          Y-wing                                BTL Y-wing
# 5                          X-wing                               T-65 X-wing
# 6                 TIE Advanced x1               Twin Ion Engine Advanced x1
# 7                         Slave 1      Firespray-31-class patrol and attack
# 8                Imperial shuttle                 Lambda-class T-4a shuttle
# 9   EF76 Nebulon-B escort frigate             EF76 Nebulon-B escort frigate
# 10               Calamari Cruiser            MC80 Liberty type Star Cruiser
# 11                         A-wing                   RZ-1 A-wing Interceptor
# 12                         B-wing                A/SF-01 B-wing starfighter
# 13               Republic Cruiser                    Consular-class cruiser
# 14                  Naboo fighter                           N-1 starfighter
# 15           Naboo Royal Starship          J-type 327 Nubian royal starship
# 16                       Scimitar                              Star Courier
# 17        J-type diplomatic barge                   J-type diplomatic barge
# 18       AA-9 Coruscant freighter              Botajef AA-9 Freighter-Liner
# 19               Jedi starfighter    Delta-7 Aethersprite-class interceptor
# 20            H-type Nubian yacht                       H-type Nubian yacht
# 21                 Star Destroyer           Imperial I-class Star Destroyer
# 22       Trade Federation cruiser        Providence-class carrier/destroyer
# 23       Theta-class T-2c shuttle                  Theta-class T-2c shuttle
# 24            T-70 X-wing fighter                       T-70 X-wing fighter
# 25                Rebel transport                    GR-75 medium transport
# 26             Droid control ship        Lucrehulk-class Droid Control Ship
# 27          Republic Assault ship           Acclamator I-class assault ship
# 28                   Solar Sailer    Punworcca 116-class interstellar sloop
# 29        Republic attack cruiser              Senator-class Star Destroyer
# 30               Naboo star skiff                         J-type star skiff
# 31               Jedi Interceptor       Eta-2 Actis-class light interceptor
# 32                        arc-170  Aggressive Reconnaissance-170 starfighte
# 33       Belbullab-22 starfighter                  Belbullab-22 starfighter
# 34                         V-wing   Alpha-3 Nimbus-class V-wing starfighter
# 35                  CR90 corvette                             CR90 corvette
# 36           Banking clan frigate             Munificent-class star frigate
#
#                                          manufacturer  cost_in_credits  \
# 0                  Kuat Drive Yards, Fondor Shipyards     1.143350e+09
# 1             Sienar Fleet Systems, Cyngus Spaceworks     2.400000e+05
# 2   Imperial Department of Military Research, Sien...     1.000000e+12
# 3                   Corellian Engineering Corporation     1.000000e+05
# 4                              Koensayr Manufacturing     1.349990e+05
# 5                                   Incom Corporation     1.499990e+05
# 6                                Sienar Fleet Systems              NaN
# 7                            Kuat Systems Engineering              NaN
# 8                                Sienar Fleet Systems     2.400000e+05
# 9                                    Kuat Drive Yards     8.500000e+06
# 10                             Mon Calamari shipyards     1.040000e+08
# 11  Alliance Underground Engineering, Incom Corpor...     1.750000e+05
# 12                                     Slayn & Korpil     2.200000e+05
# 13                  Corellian Engineering Corporation              NaN
# 14        Theed Palace Space Vessel Engineering Corps     2.000000e+05
# 15  Theed Palace Space Vessel Engineering Corps, N...              NaN
# 16                            Republic Sienar Systems     5.500000e+07
# 17  Theed Palace Space Vessel Engineering Corps, N...     2.000000e+06
# 18                                  Botajef Shipyards              NaN
# 19                           Kuat Systems Engineering     1.800000e+05
# 20        Theed Palace Space Vessel Engineering Corps              NaN
# 21                                   Kuat Drive Yards     1.500000e+08
# 22  Rendili StarDrive, Free Dac Volunteers Enginee...     1.250000e+08
# 23                                  Cygnus Spaceworks     1.000000e+06
# 24                                              Incom              NaN
# 25                              Gallofree Yards, Inc.              NaN
# 26                         Hoersch-Kessel Drive, Inc.              NaN
# 27                          Rothana Heavy Engineering              NaN
# 28            Huppla Pasa Tisc Shipwrights Collective     3.570000e+04
# 29          Kuat Drive Yards, Allanteen Six shipyards     5.900000e+07
# 30  Theed Palace Space Vessel Engineering Corps/Nu...              NaN
# 31                           Kuat Systems Engineering     3.200000e+05
# 32              Incom Corporation, Subpro Corporation     1.550000e+05
# 33                 Feethan Ottraw Scalable Assemblies     1.680000e+05
# 34                           Kuat Systems Engineering     1.025000e+05
# 35                  Corellian Engineering Corporation     3.500000e+06
# 36  Hoersch-Kessel Drive, Inc, Gwori Revolutionary...     5.700000e+07
#
#     length max_atmosphering_speed      crew  passengers  cargo_capacity  \
# 0    19000                    NaN  279144.0     38000.0    2.500000e+08
# 1       38                   1000       5.0        75.0    1.800000e+05
# 2   120000                    NaN  342953.0    843342.0    1.000000e+12
# 3    34.37                   1050       4.0         6.0    1.000000e+05
# 4       14                 1000km       2.0         0.0    1.100000e+02
# 5     12.5                   1050       1.0         0.0    1.100000e+02
# 6      9.2                   1200       1.0         0.0    1.500000e+02
# 7     21.5                   1000       1.0         6.0    7.000000e+04
# 8       20                    850       6.0        20.0    8.000000e+04
# 9      300                    800     854.0        75.0    6.000000e+06
# 10    1200                    NaN    5400.0      1200.0             NaN
# 11     9.6                   1300       1.0         0.0    4.000000e+01
# 12    16.9                    950       1.0         0.0    4.500000e+01
# 13     115                    900       9.0        16.0             NaN
# 14      11                   1100       1.0         0.0    6.500000e+01
# 15      76                    920       8.0         NaN             NaN
# 16    26.5                   1180       1.0         6.0    2.500000e+06
# 17      39                   2000       5.0        10.0             NaN
# 18     390                    NaN       NaN     30000.0             NaN
# 19       8                   1150       1.0         0.0    6.000000e+01
# 20    47.9                   8000       4.0         NaN             NaN
# 21   1,600                    975   47060.0         0.0    3.600000e+07
# 22    1088                   1050     600.0     48247.0    5.000000e+07
# 23    18.5                   2000       5.0        16.0    5.000000e+04
# 24     NaN                    NaN       1.0         NaN             NaN
# 25      90                    650       6.0        90.0    1.900000e+07
# 26    3170                    NaN     175.0    139000.0    4.000000e+09
# 27     752                    NaN     700.0     16000.0    1.125000e+07
# 28    15.2                   1600       3.0        11.0    2.400000e+02
# 29    1137                    975    7400.0      2000.0    2.000000e+07
# 30    29.2                   1050       3.0         3.0             NaN
# 31    5.47                   1500       1.0         0.0    6.000000e+01
# 32    14.5                   1000       3.0         0.0    1.100000e+02
# 33    6.71                   1100       1.0         0.0    1.400000e+02
# 34     7.9                   1050       1.0         0.0    6.000000e+01
# 35     150                    950     165.0       600.0    3.000000e+06
# 36     825                    NaN     200.0         NaN    4.000000e+07
#
#    consumables  hyperdrive_rating   MGLT                   starship_class
# 0      6 years                2.0   40.0                 Star dreadnought
# 1      1 month                1.0   70.0                    landing craft
# 2      3 years                4.0   10.0  Deep Space Mobile Battlestation
# 3     2 months                0.5   75.0                  Light freighter
# 4       1 week                1.0   80.0              assault starfighter
# 5       1 week                1.0  100.0                      Starfighter
# 6       5 days                1.0  105.0                      Starfighter
# 7      1 month                3.0   70.0                     Patrol craft
# 8     2 months                1.0   50.0       Armed government transport
# 9      2 years                2.0   40.0                      Escort ship
# 10     2 years                1.0   60.0                     Star Cruiser
# 11      1 week                1.0  120.0                      Starfighter
# 12      1 week                2.0   91.0              Assault Starfighter
# 13         NaN                2.0    NaN                    Space cruiser
# 14      7 days                1.0    NaN                      Starfighter
# 15         NaN                1.8    NaN                            yacht
# 16     30 days                1.5    NaN                  Space Transport
# 17      1 year                0.7    NaN                 Diplomatic barge
# 18         NaN                NaN    NaN                        freighter
# 19      7 days                1.0    NaN                      Starfighter
# 20         NaN                0.9    NaN                            yacht
# 21     2 years                2.0   60.0                   Star Destroyer
# 22     4 years                1.5    NaN                     capital ship
# 23     56 days                1.0    NaN                        transport
# 24         NaN                NaN    NaN                          fighter
# 25    6 months                4.0   20.0                 Medium transport
# 26    500 days                2.0    NaN               Droid control ship
# 27     2 years                0.6    NaN                     assault ship
# 28      7 days                1.5    NaN                            yacht
# 29     2 years                1.0    NaN                   star destroyer
# 30         NaN                0.5    NaN                            yacht
# 31      2 days                1.0    NaN                      starfighter
# 32      5 days                1.0  100.0                      starfighter
# 33      7 days                6.0    NaN                      starfighter
# 34    15 hours                1.0    NaN                      starfighter
# 35      1 year                2.0   60.0                         corvette
# 36     2 years                1.0    NaN                          cruiser

# %%
df_starships.shape
# Out:
# (37, 13)

# %%
df_starships['manufacturer'].nunique()
# Out:
# 28

# %%
df_starships['name'].nunique()
# Out:
# 37
