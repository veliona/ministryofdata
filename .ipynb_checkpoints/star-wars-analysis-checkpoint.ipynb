# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from math import pi
import matplotlib.colors as mcolors
from scipy import stats

from csv import reader
import pandas as pd
import matplotlib.dates as mdates
import numpy as np
from pathlib import Path
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from pysankey import sankey

from scipy.stats import shapiro
from scipy.stats import ttest_ind
from scipy.stats import f

# Google Play Store data set
characters = open('star-wars-analysis-datasets/characters.csv')
characters = pd.read_csv('star-wars-analysis-datasets/characters.csv')

sns.set()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-1c53723cc535> in <module>
#      22
#      23 # Google Play Store data set
# ---> 24 characters = open('star-wars-analysis-datasets/characters.csv')
#      25 characters = pd.read_csv('star-wars-analysis-datasets/characters.csv')
#      26
#
# FileNotFoundError: [Errno 2] No such file or directory: 'star-wars-analysis-datasets/characters.csv'

# %%
df_luke = pd.read_json('star-wars-analysis-datasets/people/Luke_Skywalker.json')

# %%
df_luke.head(100)
# Out:
#                                                        people
# birth_year                                              19BBY
# created                           2014-12-09T13:50:51.644000Z
# desc        [Luke Skywalker is a fictional character and t...
# edited                            2014-12-20T21:17:56.891000Z
# eye_color                                                blue
# films       [http://swapi.co/api/films/6/, http://swapi.co...
# gender                                                   male
# hair_color                                              blond
# height                                                    172
# homeworld                      http://swapi.co/api/planets/1/
# mass                                                       77
# name                                           Luke Skywalker
# skin_color                                               fair
# species                      [http://swapi.co/api/species/1/]
# ...
